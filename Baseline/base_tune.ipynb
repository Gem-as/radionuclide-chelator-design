# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import math

# %%
from joblib import dump, load
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import DataStructs
from rdkit.Chem import Descriptors
from rdkit.Contrib.SA_Score import sascorer
from rdkit import DataStructs
fpgen = AllChem.GetRDKitFPGenerator()

# %%
df = pd.read_csv("Информация о связывании медицинского радионуклида различными молекулами.csv")

# %%
df
# Out:
#       id                        smiles   lgK
# 0      0                CC(C)(O)C(=O)O  3.41
# 1      1              CCC(O)(CC)C(=O)O  3.25
# 2      2              O=C(O)C1(O)CCCC1  3.22
# 3      3             O=C(O)C1(O)CCCCC1  2.78
# 4      4            O=C(O)C(O)c1ccccc1  2.82
# ..   ...                           ...   ...
# 242  244  O=C(O)c1cccc([N+](=O)[O-])c1  1.64
# 243  245                  CCC(O)C(=O)O  3.13
# 244  246                 CCCC(O)C(=O)O  2.76
# 245  247               CC(C)C(O)C(=O)O  2.99
# 246  248            CC(C)(C)C(O)C(=O)O  2.86
#
# [247 rows x 3 columns]

# %%
base_smiles = []
for i in range(len(df)):
    base_smiles.append(df.iloc[i][1])

# %%
base_smiles
# Out:
# ['CC(C)(O)C(=O)O',
#  'CCC(O)(CC)C(=O)O',
#  'O=C(O)C1(O)CCCC1',
#  'O=C(O)C1(O)CCCCC1',
#  'O=C(O)C(O)c1ccccc1',
#  'CC(O)C(C)(O)C(=O)O',
#  'O=C(O)C(O)(CO)CO',
#  'O=C(O)[C@H](O)[C@@H](O)[C@H](O)[C@H](O)CO',
#  'O=C([O-])C1(O)C[C@@H](O)C(O)[C@H](O)C1',
#  'O=C(O)CCO',
#  'CC(CO)(CO)C(=O)O',
#  'COc1ccccc1C(=O)O',
#  'COc1cccc(C(=O)O)c1',
#  'COc1ccc(C(=O)O)cc1',
#  'O=C(O)CC(=O)O',
#  'CC(C(=O)O)C(=O)O',
#  'CCC(C(=O)O)C(=O)O',
#  'CCCC(C(=O)O)C(=O)O',
#  'CCCCC(C(=O)O)C(=O)O',
#  'CCCCCC(C(=O)O)C(=O)O',
#  'CC(C)(C(=O)O)C(=O)O',
#  'CCC(CC)(C(=O)O)C(=O)O',
#  'CCCC(CCC)(C(=O)O)C(=O)O',
#  'CCCCC(CCCC)(C(=O)O)C(=O)O',
#  'O=C(O)C1(C(=O)O)CCC1',
#  'O=C(O)C1(C(=O)O)CCCC1',
#  'O=C(O)CCC(=O)O',
#  'CC(CC(=O)O)C(=O)O',
#  'O=C(O)/C=C\\C(=O)O',
#  'O=C(O)/C=C/C(=O)O',
#  'O=C(O)CCCC(=O)O',
#  'O=C(O)CCCCC(=O)O',
#  'O=C(O)[C@H]1CC[C@H](C(=O)O)CC1',
#  'O=C(O)c1ccccc1C(=O)O',
#  'O=C(O)c1cccc(C(=O)O)c1',
#  'O=C(O)C[C@H](O)C(=O)O',
#  'O=C(O)[C@H](O)[C@@H](O)C(=O)O',
#  'O=C(O)COCC(=O)O',
#  'CC(OC(C)C(=O)O)C(=O)O',
#  'O=C(O)c1cccc(C(=O)O)c1C(=O)O',
#  'O=C(O)CC(O)(CC(=O)O)C(=O)O',
#  'O=C(O)c1cc(C(=O)O)c(C(=O)O)cc1C(=O)O',
#  'O=[N+]([O-])c1ccc(O)cc1',
#  'O=C(O)c1cc(S(=O)(=O)O)cc(Br)c1O',
#  'CCCN(CCCS(=O)(=O)O)c1ccc(N=O)c(O)c1',
#  'O=Nc1ccc(O)cc1O',
#  'O=Nc1c(O)ccc2ccccc12',
#  'O=S(=O)(O)c1cc2cc(S(=O)(=O)O)c(N=Nc3ccccc3[As](=O)(O)O)c(O)c2c(O)c1N=Nc1ccccc1[As](=O)(O)O',
#  'CC(=O)CC(C)=O',
#  'O=c1c(O)c(O)c1=O',
#  'O=c1cccccc1O',
#  'Cc1occc(=O)c1O',
#  'O=c1cc(CO)occ1O',
#  'Cc1oc(CO)cc(=O)c1O',
#  'O=c1cc(CO)oc(Br)c1O',
#  'O=c1cc(CO)oc(I)c1O',
#  'O=c1cc(CO)oc(CO)c1O',
#  'O=C1O[C@H]([C@@H](O)CO)C(O)=C1O',
#  'O=[N+]([O-])[O-]',
#  'O=[N+]([O-])c1cc2c(O)c(c1)COCCOCCOCCOCCOC2',
#  'C1COCCN2CCOCCOCCN(CCO1)CCOCC2',
#  'C[N+](CCCN(CC(=O)O)CC(=O)O)(CCCN(CC(=O)O)CC(=O)O)CC(=O)O',
#  'CCCCC(CN(CC(=O)O)CC(=O)O)N(CC(=O)O)CC(=O)O',
#  'CCCCCCC(CN(CC(=O)O)CC(=O)O)N(CC(=O)O)CC(=O)O',
#  'CCCC(CN(CC(=O)O)CC(=O)O)N(CC(=O)O)CC(=O)O',
#  'O=C(O)c1ccn(Cc2cc(Cn3ccc(C(=O)O)n3)c(Cn3ccc(C(=O)O)n3)cc2Cn2ccc(C(=O)O)n2)n1',
#  'O=C(O)CSCCSCC(=O)O',
#  'CCC(CN(CC(=O)O)CC(=O)O)N(CC(=O)O)CC(=O)O',
#  'O=C(O)CN1CCOCCOCCN(CC(=O)O)CCOCCOCC1',
#  'O=C(O)CN1CCOCCOCCNCCOCCOCC1',
#  'O=C(O)CN1CCOCCOCCN(CC(=O)O)CCOCC1',
#  'O=C(O)CN1CCN(CC(=O)O)CCN(CC(=O)O)CCN(CC(=O)O)CCN(CC(=O)O)CCN(CC(=O)O)CC1',
#  'O=C(O)CN1CCN(CC(=O)O)CCN(CC(=O)O)CCN(CC(=O)O)CCN(CC(=O)O)CC1',
#  'CCC(NC(C(C)=O)C(C)=O)C(C)=O',
#  'O=C(O)c1cc(S(=O)(=O)O)c2ccc(S(=O)(=O)O)cc2c1O',
#  'O=C(O)c1cc(S(=O)(=O)O)c2ccccc2c1O',
#  'O=Nc1c(O)ccc2ccc(S(=O)(=O)O)cc12',
#  'O=C(O)CN1CCN(CCCO)CCN(CC(=O)O)CCN(CC(=O)O)CC1',
#  'C1COCCOCCOCCOCCO1',
#  'O=[N+]([O-])c1cc(/N=N/c2ccc(O)c(O)c2O)c(O)c(S(=O)(=O)O)c1',
#  'O=C(O)CN(CC(=O)O)CC(C(=O)O)N(CC(=O)O)CC(=O)O',
#  'O=C(O)C(CNC(C(=O)O)C(=O)O)NC(C(=O)O)C(=O)O',
#  'CC(C)(O)C(C)(O)C(=O)O',
#  'CC(O)(CO)C(=O)O',
#  'CC[C@@H](C)n1c(-c2cccc(-c3nc4ccccc4n3[C@@H](C)CC)n2)nc2ccccc21',
#  'CC(=O)CN(CC(C)=O)Cc1ccn(-c2cccc(-n3ccc(CN(CC(C)=O)CC(C)=O)n3)n2)n1',
#  'O=C(O)CN1C(C(=O)O)CCCC1C(=O)O',
#  'CCC(O)(C(=O)O)C(C)C',
#  'CCCCCCC(C(C)=O)N(CC(C)=O)CC(C)=O',
#  'CCC(C)(O)C(=O)O',
#  'CC(O)(C(=O)O)c1ccccc1',
#  'O=C(O)c1cc(S(=O)(=O)O)cc(S(=O)(=O)O)c1O',
#  'C=C(C)C(=O)O',
#  'O=Nc1ccc2cccc(S(=O)(=O)O)c2c1O',
#  'COC(C(=O)O)c1ccccc1',
#  'OCCN(CCO)C(CCO)(CCO)CCO',
#  'O=C(O)c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O',
#  'O=C(O)CN1CCCN(CC(=O)O)Cc2cccc(n2)CN(CC(=O)O)CCC1',
#  'CC(=O)C(/N=N/c1cc(S(=O)(=O)O)cc(S(=O)(=O)O)c1O)C(C)=O',
#  'CC(=O)C(/N=N/c1ccc([N+](=O)[O-])cc1O)C(C)=O',
#  'CC(=O)C(/N=N/c1cc([N+](=O)[O-])cc(S(=O)(=O)O)c1O)C(C)=O',
#  'CC(=O)C(/N=N/c1ccccc1O)C(C)=O',
#  'CC(=O)C(/N=N/c1cc(Cl)cc(S(=O)(=O)O)c1O)C(C)=O',
#  'C=CCC(C(C)=O)C(C)=O',
#  'Oc1ccc(/N=N/c2ccc(Br)cc2)c(O)c1O',
#  'Oc1ccc(/N=N/c2ccc(Cl)cc2)c(O)c1O',
#  'Oc1ccc(/N=N/c2ccc(F)cc2)c(O)c1O',
#  'Oc1ccc(/N=N/c2ccc(I)cc2)c(O)c1O',
#  'Oc1ccc(/N=N/c2ccccc2)c(O)c1O',
#  'O=[N+](O)c1ccc(O)c(O)c1',
#  'O=C(O)c1cc(S(=O)(=O)O)ccc1O',
#  'Oc1cccc2cccnc12',
#  'O=C(O)CN1CCOCCOCCN(CC(=O)O)CCOCC1',
#  'O=C(O)CN1CCOCCOCCN(CC(=O)O)CCOCCOCC1',
#  'O=C(O)CN1CCOCCOCCNCCOCCOCC1',
#  'O=C(O)CCN1CCOCCOCCN(CCC(=O)O)CCOCCOCC1',
#  'O=C(O)CN1CCN(CC(=O)O)CCN(CC(=O)O)CC1',
#  'CC(N)C(=O)O',
#  'C=CCOC(=O)CC(C)=O',
#  'NC(CC(=O)O)C(=O)O',
#  'Nc1ncnc2c1ncn2[C@@H]1O[C@H](COP(=O)(O)OP(=O)(O)OP(=O)(O)O)C(O)C1O',
#  'c1ccc2c(c1)OCCOCCOCCOCCO2',
#  'O=[N+]([O-])c1ccc2c(c1)OCCOCCOCCOCCO2',
#  'CCCCc1ccc2c(c1)OCCOCCOCCOCCO2',
#  'CC(=O)C(/N=N\\c1cccc(/N=N/C(C(C)=O)=C(\\C)O)c1)=C(/C)O',
#  'CC(=O)C(/N=N\\c1cccc(/N=N/C(C(C)=O)=C(/O)c2ccccc2)c1)=C(\\O)c1ccccc1',
#  'CC(=O)C(/N=N\\c1ccc(/N=N/C(C(C)=O)=C(\\C)O)cc1)=C(/C)O',
#  'CC(=O)C(/N=N/c1ccc(/N=N\\C(C(C)=O)C(O)c2ccccc2)cc1)=C(\\O)c1ccccc1',
#  'O=C(O)CN(CCCN(CC(=O)O)c1cccc(C(=O)O)n1)Cc1cccc(C(=O)O)n1',
#  'O=C(O)CN(CC(=O)O)[C@@H]1CCCC[C@H]1N(CC(=O)O)CC(=O)O',
#  'O=C(O)CN1CCN(CC(=O)O)CP(=O)(O)C1',
#  'O=C(O)C(O)(O)C(=O)O',
#  'O=C(O)CN1CCNCCN(CC(=O)O)CCNCC1',
#  'O=P(O)(O)CN1CCNCCN(CP(=O)(O)O)CCNCC1',
#  'O=C(O)CN1CCN(CCNS(=O)(=O)c2ccc(O)cc2)CCN(CC(=O)O)CCN(CC(=O)O)CC1',
#  'O=C(O)CN1CCNCCN(CC(=O)O)CCN(CC(=O)O)CC1',
#  'O=P(O)(O)CN1CCN(CP(=O)(O)O)CCN(CP(=O)(O)O)CCN(CP(=O)(O)O)CC1',
#  'O=C(O)CCP(=O)(O)CN1CCN(CP(=O)(O)CCC(=O)O)CCN(CP(=O)(O)CCC(=O)O)CCN(CP(=O)(O)CCC(=O)O)CC1',
#  'c1ccc(-c2ccc3ccc4ccc(-c5ccccn5)nc4c3n2)nc1',
#  'O=C(O)C[NH+]1CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(C2)C[NH+](CC(=O)O)CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(C2)C1',
#  'O=C(O)NCCNC(=O)O',
#  'O=C(O)CCC(NCCNC(CCC(=O)O)C(=O)O)C(=O)O',
#  'O=P(O)(O)CN(CCN(CP(=O)(O)O)CP(=O)(O)O)CP(=O)(O)O',
#  'CCc1cccc(CC)c1NC(=O)CN(CC(=O)O)CC(=O)O',
#  'O=C(O)CN1CCOCCOCCN(CC(=O)O)CCOCC1',
#  'O=C(O)CN1CCOCCOCCN(CC(=O)O)CCOCCOCC1',
#  'O=C(O)c1cccc(CN2CCOCCOCCN(Cc3cccc(C(=O)O)n3)CCOCC2)n1',
#  'O=C(O)c1cccc(N2CCOCCOCCN(c3cccc(C(=O)O)n3)CCOCCOCC2)n1',
#  'Nc1ccc(CP(=O)(O)CN2CCN(C(=O)O)CCN(C(=O)O)CCN(C(=O)O)CC2)cc1',
#  'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1',
#  'O=C(O)CCP(=O)(O)CN1CCN(C(=O)O)CCN(C(=O)O)CCN(C(=O)O)CC1',
#  'O=C(O)CN1CCCN(CC(=O)O)CCN(CP(=O)(O)O)CCCN(CC(=O)O)CC1',
#  'O=C(O)CN1CCCN(CP(=O)(O)O)CCN(CP(=O)(O)O)CCCN(CP(=O)(O)O)CC1',
#  'O=C(O)CN(CC(=O)O)Cc1ccccc1O',
#  'O=C(O)CN(CCO)CC(=O)O',
#  'C=C(CC(=O)O)C(=O)O',
#  'O=C(O)CN1CCN(CC(=O)O)CC(=O)OCCOC(=O)C1',
#  'O=C(O)CN1CCN(CC(=O)O)CC(=O)OCCOCCOC(=O)C1',
#  'O=C(O)CN1CCN(CC(=O)O)CC(=O)OCCOCCOCCOC(=O)C1',
#  'O=C(O)CN1CCN(CC(=O)O)CC(=O)OCOCOCOCCOC(=O)C1',
#  'O=C(O)CN1CCOCCOCCN(CC(=O)O)CCOCC1',
#  'O=C(O)CN1CCOCCOCCN(CC(=O)O)CCOCCOCC1',
#  'CC(C(=O)O)N1CCOCCOCCN(C(C)C(=O)O)CCOCCOCC1',
#  'O=C(O)CN1CCOCCOCCNCCOCCOCC1',
#  'C[C@H](O)C(=O)O',
#  'O=C(O)CN(CCN(Cc1ccccn1)Cc1ccccn1)Cc1ccccn1',
#  'CCCCN(CCCC)C(=O)c1cccc(-c2cccc(C(=O)N(CCCC)CCCC)n2)n1',
#  'CCCCCCCCN(CCCCCCCC)C(=O)c1cccc(-c2cccc(C(=O)N(CCCCCCCC)CCCCCCCC)n2)n1',
#  'CCN(C(=O)c1cccc(-c2cccc(C(=O)N(CC)c3ccccc3)n2)n1)c1ccccc1',
#  'O=C(O)CN(CCN(Cc1ccccn1)Cc1ccccn1)CC(=O)O',
#  'O=C(O)CN(CCN(Cc1cnccn1)Cc1cnccn1)CC(=O)O',
#  'O=C(O)CC(O)C(=O)O',
#  'CCN(CC)C(=O)c1cccc(C(=O)N(CC)CC)n1',
#  'O=C(c1cccc(C(=O)N(Cc2ccccc2)Cc2ccccc2)n1)N(Cc1ccccc1)Cc1ccccc1',
#  'CC(C)N(C(=O)c1cccc(C(=O)N(C(C)C)C(C)C)n1)C(C)C',
#  'O=C(O)CCN(CCOCCN(CC(=O)O)CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CC(=O)O)Cc1ccccc1O',
#  'O=C(O)c1cccnc1',
#  'O=C(O)CN(CCOCCN(CC(=O)O)CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CCN(CC(=O)O)c1cccc(C(=O)O)n1)Cc1cccc(C(=O)O)n1',
#  'CC(=O)C(C)=O',
#  'OCc1ccc2ccc3ccc(CO)nc3c2n1',
#  'NC(=O)c1ccc2ccc3ccc(C(N)=O)nc3c2n1',
#  'N[C@@H](Cc1ccccc1)C(=O)O',
#  'O=C(c1cccc(C(=O)N(Cc2ccccc2)Cc2ccccc2)n1)N(Cc1ccccc1)Cc1ccccc1',
#  'CCN(CC)C(=O)c1cccc(C(=O)N(CC)CC)n1',
#  'CC(C)N(C(=O)c1cccc(C(=O)N(C(C)C)C(C)C)n1)C(C)C',
#  'O=C(O)[C@]1(O)C[C@@H](O)[C@@H](O)[C@H](O)C1',
#  'N[C@@H](CO)C(=O)O',
#  'O=S(=O)([O-])[O-]',
#  'O=C(O)CN1CCCN(CC(=O)O)CCN(CC(=O)O)CCCN(CC(=O)O)CC1',
#  'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O',
#  'O=C(O)C(NC1CCCCC1NC(C(=O)O)C(=O)O)C(=O)O',
#  'O=C(O)CC(NC1CCCCC1NC(CC(=O)O)C(=O)O)C(=O)O',
#  'O=C(O)C(CO)c1ccccc1',
#  'N[C@@H](Cc1c[nH]c2ccccc12)C(=O)O',
#  'CC(C)[C@H](C)C(=O)O',
#  'O=P(O)(O)C(NCCNC(c1ccccn1)P(=O)(O)O)c1ccccn1',
#  'NCC(=O)O',
#  'N[C@@H](CC(=O)O)C(=O)O',
#  'O=C(O)CNCCNCC(=O)O',
#  'O=C(O)CC(NCCNC(CC(=O)O)C(=O)O)C(=O)O',
#  'O=C(O)CC(NCC(O)CNC(CC(=O)O)C(=O)O)C(=O)O',
#  'O=C(O)CN(CCN(CC(=O)O)Cc1ccccc1O)Cc1ccccc1O',
#  'O=C(O)CN1CCN(CC(=O)O)CC(=O)NCCNC(=O)CN(CC(=O)O)CC1',
#  'O=C(O)CN1CCN(CC(=O)O)CC(=O)NCCOCCOCCNC(=O)CN(CC(=O)O)CC1',
#  'O=C(O)CN1CCNC(=O)CN(CC(=O)O)CCN(CC(=O)O)CC(=O)NCC1',
#  'O=C(O)CN1CCN(CC(=O)O)CCN(CC(=O)O)CCN(CC(=O)O)CC1',
#  'O=C(O)C(F)(OC(F)(F)C(F)(F)F)C(F)(F)F',
#  'O=C(O)CNCC(=O)O',
#  'O=C(O)CN(CC(=O)O)Cc1ccccc1',
#  'O=C(O)CN(CC(=O)O)CC(=O)O',
#  'COCCN(CC(=O)O)CC(=O)O',
#  'CSCCN(CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CCO)CCN(CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CCN(CC(=O)O)CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CC(=O)O)C1CCCCC1N(CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CCCN(CC(=O)O)CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CCCCCN(CC(=O)O)CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CCCCCCN(CC(=O)O)CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CC(=O)O)CC(O)CN(CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CCCOCCCN(CC(=O)O)CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CCSCCN(CC(=O)O)CC(=O)O)CC(=O)O',
#  'CCN(CCN(CC(=O)O)CC(=O)O)CCN(CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CCN(CCN(CC(=O)O)CC(=O)O)c1ccccc1)CC(=O)O',
#  'O=C(O)CN(CCN(CC(=O)O)CC(=O)O)CCN(CC(=O)O)CC(=O)O',
#  'C[N+](CCCN(CC(=O)O)CC(=O)O)(CCCN(CC(=O)O)CC(=O)O)CC(=O)[O-]',
#  'O=C(O)CN(CCN(CCN(CC(=O)O)CC(=O)O)CC(=O)O)CCN(CC(=O)O)CC(=O)O',
#  'O=C(O)CN(CC(=O)O)c1ccccc1N(CC(=O)O)CC(=O)O',
#  'O=C(O)c1cnccn1',
#  'O=C(O)c1ccccn1',
#  'O=C(O)CN(CC(=O)O)Cc1ccccn1',
#  'Cc1cccc(CN(CC(=O)O)CC(=O)O)n1',
#  'C1CNCCNCCNCCNCCNCCN1',
#  'O=CO',
#  'CC(=O)O',
#  'O=C(O)c1ccccc1',
#  'O=C(O)Cc1ccccc1',
#  'O=C(O)CCl',
#  'O=C(O)CI',
#  'O=C(O)c1cccc(F)c1',
#  'O=C(O)c1ccc(F)cc1',
#  'O=C(O)c1cccc([N+](=O)[O-])c1',
#  'CCC(O)C(=O)O',
#  'CCCC(O)C(=O)O',
#  'CC(C)C(O)C(=O)O',
#  'CC(C)(C)C(O)C(=O)O']

# %%
from joblib import load
import catboost

MODEL_LOGK = load("cb.joblib")

# %%
def number_of_atoms(atom_list, df):
    for i in atom_list:
        df['num_of_{}_atoms'.format(i)] = df['mol'].apply(lambda x: len(x.GetSubstructMatches(Chem.MolFromSmiles(i))))

symbols = ["C", "O", "N", "P", "S"]

def lgK_calculator(smiles):
    #get dataframe with smile
    """
    :param smiles: smiles string like "c1ccccc1"
    :return: logP value
    """
    data = [[smiles]]
    df = pd.DataFrame(data_example, columns=['smiles'])
    df['mol'] = df['smiles'].apply(lambda x: Chem.AddHs(Chem.MolFromSmiles(x)))
    df['num_of_atoms'] = df['mol'].apply(lambda x: x.GetNumAtoms())
    df['num_of_heavy_atoms'] = df['mol'].apply(lambda x: x.GetNumHeavyAtoms())
    df['tpsa'] = df['mol'].apply(lambda x: Descriptors.TPSA(x))
    df['mol_w'] = df['mol'].apply(lambda x: Descriptors.ExactMolWt(x))
    df['num_valence_electrons'] = df['mol'].apply(lambda x: Descriptors.NumValenceElectrons(x))
    df['num_heteroatoms'] = df['mol'].apply(lambda x: Descriptors.NumHeteroatoms(x))
    df['num_rings'] = df['mol'].apply(lambda x: Descriptors.RingCount(x))
    df['Fp_Density_Morgan1'] = df['mol'].apply(lambda x: Descriptors.FpDensityMorgan1(x))
    df['HeavyAtomMolWt'] = df['mol'].apply(lambda x: Descriptors.HeavyAtomMolWt(x))
    
    number_of_atoms(symbols, df)
    
    df = df.drop(columns=['smiles', 'mol'])
    
    return MODEL_LOGK.predict(df)[0]

# %%
new_mols_gen = []

# %%
import random
import re
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import DataStructs
from rdkit import RDLogger


def mutate_population(
    top_worst_mols: [str], top_best_mols: [str], num_iterations=5
) -> str:
    """
    Split 'good' and 'bad' molecules in fragments and replace one fragment in 'bad' molecule with fragment from 'good'
    molecule, make population of such mutant molecules and choose best of them
    :param top_worst_mols: best molecules from population by logP value
    :param top_best_mols: the best molecules from population by logP value
    :param num_iterations: amount of single exchanges between 'good' and 'bad' fragments
    :return: the best mutant molecule smiles string
    """
    raw_generation = []
    for mol in top_worst_mols:
        replacement_genes_bank = []
        for i in top_best_mols:
            replacement_genes_bank.extend(
                get_branches_from_smiles(
                    Chem.MolToSmiles(
                        Chem.MolFromSmiles(i), canonical=False, isomericSmiles=False
                    )
                )
            )
        mol = Chem.MolToSmiles(
            Chem.MolFromSmiles(mol), canonical=False, isomericSmiles=False
        )
        target_mol_genes = get_branches_from_smiles(mol)
        for _ in range(num_iterations):
            try:
                raw_generation.append(
                    mol.replace(
                        random.choice(target_mol_genes),
                        random.choice(replacement_genes_bank),
                        1,
                    )
                )
            except:
                pass
    raw_generation = [i for i in raw_generation if Chem.MolFromSmiles(i)]
    return sorted(raw_generation, key=lambda x: lgK_calculator(x))[0]


def search_step(smiles_pop: [str], top_to_change=5) -> [str]:
    random.shuffle(smiles_pop)
    top_worst_mols = smiles_pop[-top_to_change:]
    top_best_mols = smiles_pop[:top_to_change]

    new_mol = mutate_population(top_worst_mols, top_best_mols)
#     print(lgK_calculator(new_mol))
    new_mols_gen.append(new_mol)

    smiles_pop.pop(-1)
    smiles_pop.append(new_mol)
    
    return smiles_pop


def get_branches_from_smiles(smiles: str) -> [str]:
    """
    Get all possible branches from smiles string
    :param smiles:
    :return:
    """
    branches = re.findall(r"(\(.*?\))", smiles)
    for branch in branches:
        bracket_diff = branch.count("(") - branch.count(")")
        if bracket_diff > 0:
            branches[branches.index(branch)] = branch + ")" * bracket_diff
        else:
            branches[branches.index(branch)] = "(" * bracket_diff + branch
    return branches

# %%
cur_smiles = base_smiles.copy()

# %%
while len(set(new_mols_gen)) < 100:
#     print(len(set(new_mols_gen)))
    cur_smiles = search_step(cur_smiles)
# Out:
# [18:06:36] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:06:36] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:06:36] SMILES Parse Error: unclosed ring for input: 'CCCCc1ccc2c(O)OCCOCCOCCOCCO2'
# [18:06:36] SMILES Parse Error: unclosed ring for input: 'CCCCc1ccc2c(=O)OCCOCCOCCOCCO2'
# [18:06:36] SMILES Parse Error: unclosed ring for input: 'CCCCc1ccc2c(CP(=O))OCCOCCOCCOCCO2'
# [18:06:36] SMILES Parse Error: unclosed ring for input: 'CCCCc1ccc2c(N=Nc3ccccc3[As](=O))OCCOCCOCCOCCO2'
# [18:06:36] SMILES Parse Error: unclosed ring for input: 'CCCCc1ccc2c(O)OCCOCCOCCOCCO2'
# [18:06:37] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:37] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:37] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:37] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:37] Explicit valence for atom # 2 N, 4, is greater than permitted
# [18:06:37] Explicit valence for atom # 2 N, 4, is greater than permitted
# [18:06:37] Explicit valence for atom # 2 N, 4, is greater than permitted
# [18:06:37] Explicit valence for atom # 2 N, 4, is greater than permitted
# [18:06:37] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:37] Explicit valence for atom # 7 N, 4, is greater than permitted
# [18:06:37] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:37] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:06:37] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:37] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:37] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:37] Can't kekulize mol.  Unkekulized atoms: 2 6 9
# [18:06:37] Can't kekulize mol.  Unkekulized atoms: 2 6 9
# [18:06:37] Explicit valence for atom # 3 C, 5, is greater than permitted
# [18:06:37] Explicit valence for atom # 14 C, 5, is greater than permitted
# [18:06:37] Explicit valence for atom # 14 C, 5, is greater than permitted
# [18:06:37] Explicit valence for atom # 14 C, 5, is greater than permitted
# [18:06:38] Can't kekulize mol.  Unkekulized atoms: 1 5 8
# [18:06:38] Can't kekulize mol.  Unkekulized atoms: 1 5 8
# [18:06:38] SMILES Parse Error: unclosed ring for input: 'O=C(O)C[NH+]1CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(=O)C[NH+](CC(=O)O)CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(C2)C1'
# [18:06:38] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:38] SMILES Parse Error: unclosed ring for input: 'CC(=O)C(c1)C(C)=O'
# [18:06:38] SMILES Parse Error: unclosed ring for input: 'CCCCCC(C(c1)O)C(=O)O'
# [18:06:38] SMILES Parse Error: unclosed ring for input: 'O=C(c1)c1cc(C(=O)O)c(C(=O)O)cc1C(=O)O'
# [18:06:38] Can't kekulize mol.  Unkekulized atoms: 2 3 4 7 8
# [18:06:38] Can't kekulize mol.  Unkekulized atoms: 2 3 4 7 8
# [18:06:39] Explicit valence for atom # 25 N, 4, is greater than permitted
# [18:06:39] Explicit valence for atom # 7 C, 5, is greater than permitted
# [18:06:39] SMILES Parse Error: unclosed ring for input: 'C=CCOC(=O)CC(N=Nc1cc(Cl))=O'
# [18:06:39] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:39] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:39] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:39] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:39] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:40] SMILES Parse Error: unclosed ring for input: 'C1COCCN2CCOCCOCCN(O)CCOCC2'
# [18:06:40] SMILES Parse Error: unclosed ring for input: 'C1COCCN2CCOCCOCCN(CP(=O))CCOCC2'
# [18:06:40] SMILES Parse Error: unclosed ring for input: 'C1COCCN2CCOCCOCCN(C)CCOCC2'
# [18:06:40] SMILES Parse Error: unclosed ring for input: 'C1COCCN2CCOCCOCCN(O)CCOCC2'
# [18:06:40] SMILES Parse Error: unclosed ring for input: 'C1COCCN2CCOCCOCCN(C)CCOCC2'
# [18:06:40] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:40] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:40] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:40] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [18:06:40] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [18:06:40] SMILES Parse Error: unclosed ring for input: 'O=C(-c2cccc(C(=O)))CN1CCCN(CC(=O)O)Cc2cccc(n2)CN(CC(=O)O)CCC1'
# [18:06:40] Can't kekulize mol.  Unkekulized atoms: 1 2 3 6 8
# [18:06:40] SMILES Parse Error: unclosed ring for input: 'O=C(c1cccc(C(=O)))c1cccnc1'
# [18:06:40] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:40] Explicit valence for atom # 3 C, 5, is greater than permitted
# [18:06:40] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:40] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:40] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:40] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:40] Can't kekulize mol.  Unkekulized atoms: 2 6 9
# [18:06:40] Can't kekulize mol.  Unkekulized atoms: 2 6 9
# [18:06:40] Can't kekulize mol.  Unkekulized atoms: 2 6 9
# [18:06:40] Can't kekulize mol.  Unkekulized atoms: 2 6 9
# [18:06:41] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:41] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:41] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:41] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:42] Can't kekulize mol.  Unkekulized atoms: 2 5 6 7 8 9 10 15 16
# [18:06:42] Can't kekulize mol.  Unkekulized atoms: 2 5 6 7 8 9 10 15 16
# [18:06:42] Can't kekulize mol.  Unkekulized atoms: 2 6 8
# [18:06:42] Can't kekulize mol.  Unkekulized atoms: 2 3 9
# [18:06:42] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:42] SMILES Parse Error: unclosed ring for input: 'O=C(c1cccc(C(=O)))CN(CC(=O)O)C1CCCCC1N(CC(=O)O)CC(=O)O'
# [18:06:42] SMILES Parse Error: unclosed ring for input: 'CCC(CN(CC(c1cccc(C(=O)))O)CC(=O)O)N(CC(=O)O)CC(=O)O'
# [18:06:42] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:42] SMILES Parse Error: unclosed ring for input: 'O=C(O)CN(CCN(Cc1cnccn1)Cc1cnccn1)CC(c1cccc(C(=O)))O'
# [18:06:42] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:42] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:42] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:42] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:42] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:42] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:42] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:42] Explicit valence for atom # 4 N, 4, is greater than permitted
# [18:06:43] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:43] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:43] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:43] Explicit valence for atom # 17 N, 4, is greater than permitted
# [18:06:43] Explicit valence for atom # 3 C, 5, is greater than permitted
# [18:06:43] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:06:43] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:43] SMILES Parse Error: unclosed ring for input: 'O=C(O)C[NH+]1CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(=O)C[NH+](CC(=O)O)CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(C2)C1'
# [18:06:43] SMILES Parse Error: unclosed ring for input: 'O=C(O)C[NH+]1CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(=O)C[NH+](CC(=O)O)CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(C2)C1'
# [18:06:43] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:44] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:44] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:44] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:44] Explicit valence for atom # 1 S, 7, is greater than permitted
# [18:06:44] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:44] Explicit valence for atom # 5 C, 5, is greater than permitted
# [18:06:44] Explicit valence for atom # 5 C, 5, is greater than permitted
# [18:06:44] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:44] SMILES Parse Error: unclosed ring for input: 'O=[N+]([O-])c1ccc2c(O)OCCOCCOCCOCCO2'
# [18:06:44] SMILES Parse Error: unclosed ring for input: 'O=[N+]([O-])c1ccc2c(=O)OCCOCCOCCOCCO2'
# [18:06:44] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:45] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:45] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:45] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:45] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:45] SMILES Parse Error: unclosed ring for input: 'C1COCCN2CCOCCOCCN(=O)CCOCC2'
# [18:06:45] SMILES Parse Error: unclosed ring for input: 'C1COCCN2CCOCCOCCN(C(=O))CCOCC2'
# [18:06:45] SMILES Parse Error: unclosed ring for input: 'C1COCCN2CCOCCOCCN(C(=O))CCOCC2'
# [18:06:45] SMILES Parse Error: unclosed ring for input: 'C1COCCN2CCOCCOCCN(=O)CCOCC2'
# [18:06:45] SMILES Parse Error: unclosed ring for input: 'C1COCCN2CCOCCOCCN(CC(=O))CCOCC2'
# [18:06:45] SMILES Parse Error: unclosed ring for input: 'C=CCOC(C2)CC(C)=O'
# [18:06:45] Explicit valence for atom # 9 N, 4, is greater than permitted
# [18:06:45] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:45] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:45] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:45] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:45] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:45] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [18:06:45] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [18:06:45] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:06:45] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:46] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 15
# [18:06:46] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 9
# [18:06:46] SMILES Parse Error: unclosed ring for input: 'Cc1occc(CCO1)c1O'
# [18:06:46] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 7
# [18:06:46] SMILES Parse Error: unclosed ring for input: 'Cc1occc(CCO1)c1O'
# [18:06:46] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [18:06:46] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [18:06:46] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:46] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:46] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:46] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:46] Explicit valence for atom # 3 N, 4, is greater than permitted
# [18:06:46] Explicit valence for atom # 3 N, 4, is greater than permitted
# [18:06:46] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:06:46] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:06:46] SMILES Parse Error: unclosed ring for input: 'O=[N+]([O-])c1ccc2c(CC(=O))OCCOCCOCCOCCO2'
# [18:06:46] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:46] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [18:06:46] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [18:06:46] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:46] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:46] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:46] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 15
# [18:06:46] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:47] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:47] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:47] SMILES Parse Error: unclosed ring for input: 'O=C(O)c1ccc(N=Nc2ccc(Br))cc1'
# [18:06:47] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:47] SMILES Parse Error: unclosed ring for input: 'O=C(c1cccc(C(=O)))CN(CCN(Cc1cnccn1)Cc1cnccn1)CC(=O)O'
# [18:06:47] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [18:06:47] SMILES Parse Error: unclosed ring for input: 'O=C(c1cccc(C(=O)))CN1CCN(CCCO)CCN(CC(=O)O)CCN(CC(=O)O)CC1'
# [18:06:47] Can't kekulize mol.  Unkekulized atoms: 2 6 9
# [18:06:47] SMILES Parse Error: unclosed ring for input: 'O=c1cc(Br)oc(c1)c1O'
# [18:06:47] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:47] SMILES Parse Error: unclosed ring for input: 'O=C(c1)c1cccnc1'
# [18:06:47] SMILES Parse Error: unclosed ring for input: 'O=C(c1cccc(C(=O)))c1cccnc1'
# [18:06:47] SMILES Parse Error: unclosed ring for input: 'CC(c1cccc(C(=O)))(O)C(=O)O'
# [18:06:47] SMILES Parse Error: unclosed ring for input: 'O=C(c1)c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O'
# [18:06:47] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:47] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:47] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:47] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:48] Explicit valence for atom # 13 C, 5, is greater than permitted
# [18:06:48] SMILES Parse Error: unclosed ring for input: 'O=C(-c2cccc(-c3nc4ccccc4n3C(C)))c1cnccn1'
# [18:06:48] SMILES Parse Error: unclosed ring for input: 'O=C(-c2cccc(-c3nc4ccccc4n3C(C)))CC(O)C(=O)O'
# [18:06:48] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:06:48] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:06:48] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:48] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:48] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:48] Explicit valence for atom # 2 N, 4, is greater than permitted
# [18:06:49] SMILES Parse Error: unclosed ring for input: 'O=C(c1)c1cc(S(=O)(=O)O)ccc1O'
# [18:06:49] SMILES Parse Error: unclosed ring for input: 'O=Nc1ccc2cccc(S(c1)(=O)O)c2c1O'
# [18:06:49] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:49] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:49] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:50] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:06:50] Can't kekulize mol.  Unkekulized atoms: 3 4 5 6 9
# [18:06:50] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 16
# [18:06:50] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:50] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:50] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:50] Explicit valence for atom # 7 C, 5, is greater than permitted
# [18:06:50] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:50] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:51] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:51] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:51] SMILES Parse Error: unclosed ring for input: 'O=C(c1)c1cc(S(=O)(=O)O)c2ccccc2c1O'
# [18:06:51] SMILES Parse Error: unclosed ring for input: 'O=C(c1)c1cc([N+](=O)[O-])cc([N+](=O)[O-])c1O'
# [18:06:51] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:51] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:51] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:51] Explicit valence for atom # 13 C, 5, is greater than permitted
# [18:06:51] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:51] Explicit valence for atom # 17 N, 4, is greater than permitted
# [18:06:51] Explicit valence for atom # 17 N, 4, is greater than permitted
# [18:06:51] Explicit valence for atom # 17 N, 4, is greater than permitted
# [18:06:51] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:51] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:51] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:52] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:52] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:52] SMILES Parse Error: unclosed ring for input: 'O=C(N=Nc1cccc(N=NC(C(C))))CN(CC(=O)O)Cc1ccccc1'
# [18:06:52] SMILES Parse Error: unclosed ring for input: 'O=C(N=Nc1cccc(N=NC(C(C))))CN(CC(=O)O)Cc1ccccc1'
# [18:06:52] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:52] Explicit valence for atom # 4 C, 5, is greater than permitted
# [18:06:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:53] Explicit valence for atom # 20 C, 5, is greater than permitted
# [18:06:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:53] SMILES Parse Error: unclosed ring for input: 'O=[N+](n2)c1ccc(O)c(O)c1'
# [18:06:53] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:06:53] SMILES Parse Error: unclosed ring for input: 'c1ccc2c(=O)OCCOCCOCCOCCO2'
# [18:06:53] SMILES Parse Error: unclosed ring for input: 'c1ccc2c(=O)OCCOCCOCCOCCO2'
# [18:06:53] non-ring atom 8 marked aromatic
# [18:06:53] SMILES Parse Error: unclosed ring for input: 'c1ccc2c(O)OCCOCCOCCOCCO2'
# [18:06:53] SMILES Parse Error: unclosed ring for input: 'c1ccc2c(O)OCCOCCOCCOCCO2'
# [18:06:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:53] SMILES Parse Error: unclosed ring for input: 'O=C(n2)CN1CCCN(CP(=O)(O)O)CCN(CP(=O)(O)O)CCCN(CP(=O)(O)O)CC1'
# [18:06:53] Can't kekulize mol.  Unkekulized atoms: 2 5 6 7 8 9 10 15 16
# [18:06:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:53] Can't kekulize mol.  Unkekulized atoms: 2 5 6 7 8 9 10 11 12
# [18:06:53] SMILES Parse Error: unclosed ring for input: 'O=Nc1c(-c2cccc(-c3nc4ccccc4n3C(C)))ccc2ccccc12'
# [18:06:53] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:53] SMILES Parse Error: unclosed ring for input: 'O=C(O)CN1CCN(CC(-c2cccc(-c3nc4ccccc4n3C(C)))O)CP(=O)(O)C1'
# [18:06:53] Can't kekulize mol.  Unkekulized atoms: 2 3 9
# [18:06:54] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:54] Explicit valence for atom # 2 C, 5, is greater than permitted
# [18:06:54] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:54] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:54] Explicit valence for atom # 14 C, 5, is greater than permitted
# [18:06:54] Explicit valence for atom # 14 C, 5, is greater than permitted
# [18:06:54] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:54] SMILES Parse Error: unclosed ring for input: 'O=C(O)CN1CCN(CC(-c2cccc(C(=O)))O)CC(=O)OCCOC(=O)C1'
# [18:06:54] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:54] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:54] SMILES Parse Error: unclosed ring for input: 'O=C(C=O)CCCC(-c2cccc(C(=O)))O'
# [18:06:54] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:54] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:54] SMILES Parse Error: unclosed ring for input: 'O=C(c1cccc(C(=O)))C(O)C(O)C(=O)O'
# [18:06:54] SMILES Parse Error: unclosed ring for input: 'O=C(c1cccc(C(=O)))C(O)C(O)C(=O)O'
# [18:06:55] Explicit valence for atom # 2 C, 5, is greater than permitted
# [18:06:55] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:55] SMILES Parse Error: unclosed ring for input: 'O=C(N=Nc2ccc(Cl))c1cccc(C(=O)O)c1C(=O)O'
# [18:06:55] Can't kekulize mol.  Unkekulized atoms: 2 5 6 7 8 9 10 11 12
# [18:06:55] Can't kekulize mol.  Unkekulized atoms: 2 5 6 7 8 9 10 11 12
# [18:06:55] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:55] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:55] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:55] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:55] Explicit valence for atom # 4 C, 5, is greater than permitted
# [18:06:55] Explicit valence for atom # 19 N, 4, is greater than permitted
# [18:06:55] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:55] Explicit valence for atom # 3 C, 5, is greater than permitted
# [18:06:56] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:56] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:56] Can't kekulize mol.  Unkekulized atoms: 2 3 4 7 8
# [18:06:56] Can't kekulize mol.  Unkekulized atoms: 2 3 4 7 8
# [18:06:56] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:06:56] Explicit valence for atom # 1 S, 7, is greater than permitted
# [18:06:56] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:56] Explicit valence for atom # 8 N, 4, is greater than permitted
# [18:06:56] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:56] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:56] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:56] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:57] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:57] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 16
# [18:06:57] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:57] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:57] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:57] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:57] SMILES Parse Error: unclosed ring for input: 'c1ccc2c(C)OCCOCCOCCOCCO2'
# [18:06:57] SMILES Parse Error: unclosed ring for input: 'c1ccc2c(C)OCCOCCOCCOCCO2'
# [18:06:57] SMILES Parse Error: unclosed ring for input: 'c1ccc2c(CO)OCCOCCOCCOCCO2'
# [18:06:57] SMILES Parse Error: unclosed ring for input: 'c1ccc2c(=O)OCCOCCOCCOCCO2'
# [18:06:57] SMILES Parse Error: unclosed ring for input: 'c1ccc2c(=O)OCCOCCOCCOCCO2'
# [18:06:57] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:57] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:57] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 15
# [18:06:57] Can't kekulize mol.  Unkekulized atoms: 1 2 3 4 15
# [18:06:57] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:57] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:57] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:06:57] SMILES Parse Error: unclosed ring for input: 'O=[N+]([O-])c1ccc2c(O)OCCOCCOCCOCCO2'
# [18:06:57] SMILES Parse Error: unclosed ring for input: 'O=[N+]([O-])c1ccc2c(OC(C))OCCOCCOCCOCCO2'
# [18:06:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:58] SMILES Parse Error: unclosed ring for input: 'O=C(N=Nc1cccc(N=NC(C(C))))CN(CCN(CC(=O)O)Cc1ccccc1O)Cc1ccccc1O'
# [18:06:58] SMILES Parse Error: unclosed ring for input: 'C=CCOC(N=Nc1cccc(N=NC(C(C))))CC(CC=O)=O'
# [18:06:58] Explicit valence for atom # 7 C, 5, is greater than permitted
# [18:06:58] SMILES Parse Error: unclosed ring for input: 'C=CCOC(=O)CC(N=Nc1cccc(N=NC(C(C))))=O'
# [18:06:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:58] SMILES Parse Error: unclosed ring for input: 'CC(N=Nc1cccc(N=NC(C(C))))(C)C(O)C(=O)O'
# [18:06:58] SMILES Parse Error: unclosed ring for input: 'CC(C)(C)C(O)C(N=Nc1ccc(N=NC(C(C))))O'
# [18:06:58] SMILES Parse Error: unclosed ring for input: 'O=C(O)C[NH+]1CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(O)C[NH+](CC(=O)O)CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(C2)C1'
# [18:06:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:58] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:58] Explicit valence for atom # 3 N, 4, is greater than permitted
# [18:06:59] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:06:59] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:59] SMILES Parse Error: unclosed ring for input: 'O=C(O)c1ccc(C2)cc1'
# [18:06:59] SMILES Parse Error: unclosed ring for input: 'O=C(O)CN1CCN(CC(C2)O)CC(=O)OCCOCCOC(=O)C1'
# [18:06:59] SMILES Parse Error: unclosed ring for input: 'CC(O)C(C2)O'
# [18:06:59] SMILES Parse Error: unclosed ring for input: 'O=C(N=Nc1cccc(N=NC(C(C))))CCO'
# [18:06:59] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:59] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:59] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:59] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:06:59] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:00] Explicit valence for atom # 8 N, 4, is greater than permitted
# [18:07:00] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:07:00] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:07:00] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:07:00] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:00] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:00] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:00] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:01] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:01] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:01] SMILES Parse Error: unclosed ring for input: 'O=C(O)CC(NCCNC(CC(c1cccc(C(=O)))O)C(=O)O)C(=O)O'
# [18:07:01] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [18:07:01] Can't kekulize mol.  Unkekulized atoms: 2 6 7
# [18:07:02] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:02] SMILES Parse Error: unclosed ring for input: 'O=[PH](=O)(N=Nc1cc([N+](=O)))CN1CCN(CP(=O)(O)O)CCN(CP(=O)(O)O)CCN(CP(=O)(O)O)CC1'
# [18:07:02] Explicit valence for atom # 1 P, 8, is greater than permitted
# [18:07:02] SMILES Parse Error: unclosed ring for input: 'O=C(O)CN(CCCCCCN(CC(N=Nc1cc([N+](=O)))O)CC(=O)O)CC(=O)O'
# [18:07:02] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:02] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:02] SMILES Parse Error: unclosed ring for input: 'O=C(-c2ccc3ccc4ccc(-c5ccccn5))c1cnccn1'
# [18:07:02] SMILES Parse Error: unclosed ring for input: 'O=C(n2)c1cnccn1'
# [18:07:02] SMILES Parse Error: unclosed ring for input: 'O=C(c1)c1cnccn1'
# [18:07:03] SMILES Parse Error: unclosed ring for input: 'O=C(N=Nc1ccc(N=NC(C(C))))CN(CCCCCN(CC(=O)O)CC(=O)O)CC(=O)O'
# [18:07:03] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:03] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:03] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:03] SMILES Parse Error: unclosed ring for input: 'CCC(O)C(-c2ccc3ccc4ccc(-c5ccccn5))O'
# [18:07:03] SMILES Parse Error: unclosed ring for input: 'CCC(O)C(-c2ccc3ccc4ccc(-c5ccccn5))O'
# [18:07:03] Explicit valence for atom # 25 N, 4, is greater than permitted
# [18:07:03] SMILES Parse Error: unclosed ring for input: 'O=c1cc(-c2ccc3ccc4ccc(-c5ccccn5))oc(Br)c1O'
# [18:07:03] SMILES Parse Error: unclosed ring for input: 'O=c1cc(CO)oc(-c2ccc3ccc4ccc(-c5ccccn5))c1O'
# [18:07:03] Can't kekulize mol.  Unkekulized atoms: 2 3 9
# [18:07:03] SMILES Parse Error: unclosed ring for input: 'O=C(O)CN(CCCCCN(CC(-c2ccc3ccc4ccc(-c5ccccn5))O)CC(=O)O)CC(=O)O'
# [18:07:03] SMILES Parse Error: unclosed ring for input: 'O=[N+](c1)c1ccc(O)c(O)c1'
# [18:07:03] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:07:03] Explicit valence for atom # 1 S, 7, is greater than permitted
# [18:07:03] SMILES Parse Error: unclosed ring for input: 'O=C(c1)Cc1ccccc1'
# [18:07:03] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:03] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:03] Can't kekulize mol.  Unkekulized atoms: 1 5 8
# [18:07:03] Can't kekulize mol.  Unkekulized atoms: 1 3 6 7 10
# [18:07:03] Can't kekulize mol.  Unkekulized atoms: 2 5 6 7 8 9 10 11 12
# [18:07:03] Can't kekulize mol.  Unkekulized atoms: 2 5 6 7 8 9 10 11 12
# [18:07:03] Can't kekulize mol.  Unkekulized atoms: 2 5 6 7 8 9 10 11 12
# [18:07:03] Explicit valence for atom # 9 N, 4, is greater than permitted
# [18:07:03] Explicit valence for atom # 3 C, 5, is greater than permitted
# [18:07:04] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:04] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:04] Explicit valence for atom # 3 C, 5, is greater than permitted
# [18:07:04] Explicit valence for atom # 3 C, 5, is greater than permitted
# [18:07:04] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:07:04] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:04] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:04] Explicit valence for atom # 7 C, 5, is greater than permitted
# [18:07:04] Explicit valence for atom # 4 C, 5, is greater than permitted
# [18:07:04] SMILES Parse Error: unclosed ring for input: 'NC(-c2ccc3ccc4ccc(-c5ccccn5))c1ccc2ccc3ccc(C(N)=O)nc3c2n1'
# [18:07:04] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:07:04] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:07:04] Explicit valence for atom # 1 N, 4, is greater than permitted
# [18:07:04] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:05] SMILES Parse Error: unclosed ring for input: 'O=C(N=Nc2ccc(Cl))c1cccnc1'
# [18:07:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:05] SMILES Parse Error: unclosed ring for input: 'CCC(O)(CC)C(N=Nc1cc([N+](=O)))O'
# [18:07:05] SMILES Parse Error: unclosed ring for input: 'CCC(N=Nc1cc([N+](=O)))(CC)C(=O)O'
# [18:07:05] SMILES Parse Error: unclosed ring for input: 'CCC(O)(N=Nc1cc([N+](=O)))C(=O)O'
# [18:07:05] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:07:05] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:07:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:05] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:07:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:05] SMILES Parse Error: unclosed ring for input: 'C=CCOC(c1cccc(C(=O)))CC(C)=O'
# [18:07:05] Explicit valence for atom # 7 C, 5, is greater than permitted
# [18:07:05] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:07:06] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:07:06] SMILES Parse Error: unclosed ring for input: 'C=CCOC(N=Nc1ccc([N+](=O)))CC(CC=O)=O'
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] SMILES Parse Error: unclosed ring for input: 'CC(CN2CCOCCOCCN(Cc3cccc(C(=O))))(C(=O)O)C(=O)O'
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:06] SMILES Parse Error: unclosed ring for input: 'O=[N+]([O-])c1ccc2c(CC(=O))OCCOCCOCCOCCO2'
# [18:07:06] SMILES Parse Error: unclosed ring for input: 'O=[N+]([O-])c1ccc2c(CC(=O))OCCOCCOCCOCCO2'
# [18:07:06] SMILES Parse Error: unclosed ring for input: 'O=[N+]([O-])c1ccc2c(C(=O))OCCOCCOCCOCCO2'
# [18:07:06] SMILES Parse Error: unclosed ring for input: 'O=C(-c2ccc3ccc4ccc(-c5ccccn5))CC(NCCNC(CC(=O)O)C(=O)O)C(=O)O'
# [18:07:06] SMILES Parse Error: unclosed ring for input: 'O=C(-c2ccc3ccc4ccc(-c5ccccn5))C1(O)CCCC1'
# [18:07:06] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:07:06] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:07:06] Can't kekulize mol.  Unkekulized atoms: 2 3 4 5 6 7 8 9 10 13 14 15 16
# [18:07:07] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:07] Explicit valence for atom # 24 N, 4, is greater than permitted
# [18:07:07] SMILES Parse Error: unclosed ring for input: 'O=C(O)C[NH+]1CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(CC(=O))C[NH+](CC(=O)O)CC[NH+](CC(=O)O)CC2=C(O)C(=O)C=C(C2)C1'
# [18:07:07] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:07] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:07] SMILES Parse Error: unclosed ring for input: 'O=C(O)CN1CCN(CC(c1cccc(C(=O)))O)CC(=O)NCCNC(=O)CN(CC(=O)O)CC1'
# [18:07:07] SMILES Parse Error: unclosed ring for input: 'O=C(c1cccc(C(=O)))CN(CC(=O)O)Cc1ccccc1O'
# [18:07:07] SMILES Parse Error: unclosed ring for input: 'O=C(O)C(CNC(C(N=Nc2ccc(F))O)C(=O)O)NC(C(=O)O)C(=O)O'
# [18:07:07] SMILES Parse Error: unclosed ring for input: 'O=C(N=Nc2ccc(F))C(CNC(C(=O)O)C(=O)O)NC(C(=O)O)C(=O)O'
# [18:07:07] SMILES Parse Error: unclosed ring for input: 'O=C(O)c1cc(S(c1cccc(C(=O)))(=O)O)c2ccc(S(=O)(=O)O)cc2c1O'
# [18:07:07] SMILES Parse Error: unclosed ring for input: 'O=C(O)c1cc(S(c1cccc(C(=O)))(=O)O)c2ccc(S(=O)(=O)O)cc2c1O'
# [18:07:07] Can't kekulize mol.  Unkekulized atoms: 1 2 3 6 8
# [18:07:07] Explicit valence for atom # 1 C, 5, is greater than permitted
# [18:07:07] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 7
# [18:07:07] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 7
# [18:07:07] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 11
# [18:07:07] Can't kekulize mol.  Unkekulized atoms: 1 3 4 5 11
# [18:07:07] Explicit valence for atom # 3 N, 4, is greater than permitted

# %%
print(len(set(new_mols_gen)))
# Out:
# 100

# %%
send_df = pd.DataFrame(new_mols_gen)

# %%
send_df.to_csv('base_tune_first_submit.csv', index=False, header=False)
